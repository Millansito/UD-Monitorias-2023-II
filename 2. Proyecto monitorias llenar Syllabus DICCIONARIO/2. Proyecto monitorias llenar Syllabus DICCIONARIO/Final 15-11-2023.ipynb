# %%
from google.colab import files
import openpyxl
import json

# Subir el archivo JSON a Google Colab
uploaded_json = files.upload()

# Obtener el nombre del archivo JSON subido (asumiendo que subes solo un archivo)
archivo_json = list(uploaded_json.keys())[0]

# Cargar los datos desde el archivo JSON
with open(archivo_json, 'r') as json_file:
    datos_curso = json.load(json_file)

# Obtener el nombre del archivo Excel subido (asumiendo que subes solo un archivo)
uploaded_excel = files.upload()
archivo_excel = list(uploaded_excel.keys())[0]

# Cargar el libro de Excel
libro_excel = openpyxl.load_workbook(archivo_excel)

# Seleccionar la primera hoja del libro
hoja_excel = libro_excel.active

# Buscar la información del semestre en el archivo JSON
semestre = datos_curso.get("Semestre")


# Buscar la celda D7 y guardar la información
celda_d7 = hoja_excel['C5']
celda_d7.value = semestre

# Guardar el libro de Excel con la información actualizada
libro_excel.save('informacion_actualizada.xlsx')

# Descargar el archivo Excel actualizado
files.download('informacion_actualizada.xlsx')
# Out:
#      <input type="file" id="files-d2bccf10-2b06-4614-96bc-2de02c39166d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2bccf10-2b06-4614-96bc-2de02c39166d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import openpyxl
import json

# Subir el archivo JSON a Google Colab
uploaded_json = files.upload()

# Obtener el nombre del archivo JSON subido (asumiendo que subes solo un archivo)
archivo_json = list(uploaded_json.keys())[0]

# Cargar los datos desde el archivo JSON
with open(archivo_json, 'r') as json_file:
    datos_curso = json.load(json_file)

# Obtener el nombre del archivo Excel subido (asumiendo que subes solo un archivo)
uploaded_excel = files.upload()
archivo_excel = list(uploaded_excel.keys())[0]

# Cargar el libro de Excel
libro_excel = openpyxl.load_workbook(archivo_excel)

# Seleccionar la primera hoja del libro
hoja_excel = libro_excel.active

# Definir las claves y celdas correspondientes
claves_celdas = {
    "Código del Espacio": "C5",
    "Espacio Académico": "C4",
    "Teórico": "B13",
    "Teórico-práctico": "G13",
    "Práctico": "D13",
    "Número de Créditos": "C6",
    "Horas Trabajo Directo": "E7",
    "Horas Trabajo Colaborativo": "G7",
    "Horas Trabajo Autónomo": "I7",
    "Básico": "B11",
    "Complementario": "D11",
    "Intríseco": "G11",
    "Extrínseco": "I11",
    "Clase magistral": "B15",
    "Seminario": "E15",
    "Seminario-Taller": "I15",
    "Taller": "B16",
    "Prácticas": "E16",
    "Proyectos con tutoría": "I16",
    "Conocimientos previos del curso": "A19",
    #"Contenidos y Unidades Temáticas": "A33",
    "Enfoque de Aprendizaje y Enseñanza": "A35",
   # "Materiales de Estudio": "A47",
}

# Actualizar las celdas en el archivo Excel con la información del JSON
for clave, celda in claves_celdas.items():
    valor = datos_curso.get(clave, "")
    hoja_excel[celda].value = valor

# Guardar el libro de Excel con la información actualizada
libro_excel.save('informacion_actualizada.xlsx')

# Descargar el archivo Excel actualizado
files.download('informacion_actualizada.xlsx')
# Out:
#      <input type="file" id="files-a4b143e1-74fa-47b6-a478-c721d06cf96a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4b143e1-74fa-47b6-a478-c721d06cf96a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import openpyxl
import json
import os

# Subir el archivo JSON a Google Colab
uploaded_json = files.upload()

# Obtener el nombre del archivo JSON subido (asumiendo que subes solo un archivo)
archivo_json = list(uploaded_json.keys())[0]

# Cargar los datos desde el archivo JSON
with open(archivo_json, 'r') as json_file:
    datos_curso = json.load(json_file)

# Obtener el nombre del archivo Excel subido (asumiendo que subes solo un archivo)
uploaded_excel = files.upload()
archivo_excel = list(uploaded_excel.keys())[0]

# Cargar el libro de Excel
libro_excel = openpyxl.load_workbook(archivo_excel)

# Seleccionar la primera hoja del libro
hoja_excel = libro_excel.active

# Definir las claves y celdas correspondientes
claves_celdas = {
    "Código del Espacio": "C5",
    "Espacio Académico": "C4",
    "Teórico": "B13",
    "Teórico-práctico": "G13",
    "Práctico": "D13",
    "Número de Créditos": "C6",
    "Horas Trabajo Directo": "E7",
    "Horas Trabajo Colaborativo": "G7",
    "Horas Trabajo Autónomo": "I7",
    "Básico": "B11",
    "Complementario": "D11",
    "Intríseco": "G11",
    "Extrínseco": "I11",
    "Clase magistral": "B15",
    "Seminario": "E15",
    "Seminario-Taller": "I15",
    "Taller": "B16",
    "Prácticas": "E16",
    "Proyectos con tutoría": "I16",
    "Conocimientos previos del curso": "A19",
    "Contenidos y Unidades Temáticas": "A33",
    "Enfoque de Aprendizaje y Enseñanza": "A35",
    "Materiales de Estudio": "A47",
    "Proyecto curricular": "C2",
    "Plan de Estudios": "H2",
    "Justificacion Del Espacio": "A21",
    "Objetivos":"A23",
    "Competencias":"A26",
    "Metodologia":"A35",
    "Resultados de Aprendizaje1":"G26",
    "Resultados de Aprendizaje2":"G27",
    "Resultados de Aprendizaje3":"G28",
    "Resultados de Aprendizaje4":"G29",
    "Resultados de Aprendizaje5":"G30",
    "Resultados de Aprendizaje6":"G31"





}

# Actualizar las celdas en el archivo Excel con la información del JSON
for clave, celda in claves_celdas.items():
    valor = datos_curso.get(clave, "")
    hoja_excel[celda].value = valor

# Guardar el libro de Excel con la información actualizada
nombre_archivo_excel = os.path.splitext(archivo_json)[0] + ".xlsx"
libro_excel.save(nombre_archivo_excel)

# Descargar el archivo Excel actualizado
files.download(nombre_archivo_excel)
# Out:
#      <input type="file" id="files-2a0c583a-284c-44e9-bfe1-565cb3f48e53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a0c583a-284c-44e9-bfe1-565cb3f48e53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
