# %%
import spacy

# %%
# !pip install spacy
# !python -m spacy download es_core_news_sm

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a984b9e6-0ee5-4dc2-a847-0955a5c21f1d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a984b9e6-0ee5-4dc2-a847-0955a5c21f1d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install pypdf2

# %%
# !pip install PyPDF2
import PyPDF2

# %%
from PyPDF2 import PdfReader

def pdf_to_text(filename):
    with open(filename, 'rb') as file:
        reader = PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()  # Usa extract_text en lugar de extractText
    return text

pdf_filename = list(uploaded.keys())[0]
pdf_text = pdf_to_text(pdf_filename)

# %%
print(pdf_text)

# %%
teoria = text.split("PROGRAMA POR SEMANAS")[1:]
ProgramacionSemana=teoria[0]

semana = ProgramacionSemana.split("SEMANA")[1:17]

for j in range(16):

  #print(semana[j], end="\n")
  texto[j] = semana[j]
  texto2[j]= texto.replace("ª", "")
  print(texto2[j])

# %%
sections = {}

# Separar el contenido basado en los títulos
univ_part, _, rest = text_content.partition("Universidad distital")
_, prog_sintetico_content = rest.partition("Programa sintetico")

# Asignar cada sección al diccionario resultante
sections["Universidad distital"] = univ_part.strip()
sections["Programa sintetico"] = prog_sintetico_content.strip()

# %%
import json

data = {
    "contenido": pdf_text
}

# Si deseas guardar el JSON en un archivo:
with open("output.json", "w") as json_file:
    json.dump(data, json_file)

# Mostrar el contenido en formato JSON:
print(json.dumps(data, indent=4))
# Out:
# {
# ...

# %%
programa_sintetico_data = {}

for item in data:
    if item.get("contenido") == "Programa sintético":
        programa_sintetico_data["Programa sintético"] = item["contenido"]

# Si solo deseas mantener el contenido sin el título redundante:
# programa_sintetico_data = item["contenido"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-749cf30cb38f> in <cell line: 3>()
#       2
#       3 for item in data:
# ----> 4     if item.get(pdf_txt) == "Programa sintético":
#       5         programa_sintetico_data["Programa sintético"] = item["contenido"]
#       6
#
# AttributeError: 'str' object has no attribute 'get'

# %%
import json

data = {
    "contenido": output_txt
}

with open("output_txt.json", "w") as json_file:
    json.dump(data, json_file)

# %%
import json

# Reemplaza 'tu_archivo.json' con el nombre de tu archivo subido, si es diferente
with open('output_txt.json', 'r') as file:
    data = json.load(file)

# Imprimir el contenido del archivo .json
print(json.dumps(data, indent=4))
# Out:
# {
#     "contenido": "Syllabus.txt"
# }

# %%
# !pip install spacy
# !python -m spacy download es_core_news_sm

# %%
import spacy

# Carga el modelo en español
nlp = spacy.load("es_core_news_sm")

# Leer el archivo "Poemas.txt"
with open("Poemas.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Procesar el texto con SpaCy
doc = nlp(text)


# Dividir el documento por párrafos. En este caso, consideraremos que un párrafo termina cuando hay un doble salto de línea.
paragraphs = text.split("\n\n")

# Procesar cada párrafo con SpaCy (opcional, si quieres hacer un análisis más profundo por párrafo)
for para in paragraphs:
    paragraph_doc = nlp(para)
    # Aquí puedes hacer análisis adicionales con el objeto paragraph_doc, como tokenización, detección de entidades, etc.
    print(paragraph_doc)
