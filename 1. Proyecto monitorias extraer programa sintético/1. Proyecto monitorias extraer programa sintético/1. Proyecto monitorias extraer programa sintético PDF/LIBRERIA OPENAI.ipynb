# %%
# Instala las bibliotecas necesarias
# !pip install PyPDF2 openai

# Importa las bibliotecas
import PyPDF2
import openai

# Configura tu clave de API de OpenAI
openai.api_key = "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"

# Define la función para leer el PDF
def leer_pdf(nombre_archivo):
    pdf_text = ""
    with open(nombre_archivo, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfFileReader(pdf_file)
        for page_num in range(pdf_reader.numPages):
            page = pdf_reader.getPage(page_num)
            pdf_text += page.extractText()
    return pdf_text

# Nombre del archivo PDF que deseas leer
nombre_archivo_pdf = "aaa.pdf"

# Lee el contenido del PDF
contenido_pdf = leer_pdf(nombre_archivo_pdf)

# Pregunta a OpenAI sobre el contenido del PDF
pregunta = "¿Cuál es la información principal en el PDF?"
respuesta = openai.Completion.create(
    engine="text-davinci-002",
    prompt=f"PDF: {contenido_pdf}\nPregunta: {pregunta}\nRespuesta:",
    max_tokens=50  # Ajusta este valor según tus necesidades
)

# Imprime la respuesta de OpenAI
print(respuesta.choices[0].text)
# Out:
# ...
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# <ipython-input-13-97694d9cdb67> in <cell line: 25>()
#      23
#      24 # Lee el contenido del PDF
# ---> 25 contenido_pdf = leer_pdf(nombre_archivo_pdf)
#      26
#      27 # Pregunta a OpenAI sobre el contenido del PDF
#
# <ipython-input-13-97694d9cdb67> in leer_pdf(nombre_archivo)
#      13     pdf_text = ""
#      14     with open(nombre_archivo, 'rb') as pdf_file:
# ---> 15         pdf_reader = PyPDF2.PdfFileReader(pdf_file)
#      16         for page_num in range(pdf_reader.numPages):
#      17             page = pdf_reader.getPage(page_num)
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/_reader.py in __init__(self, *args, **kwargs)
#    1972 class PdfFileReader(PdfReader):  # pragma: no cover
#    1973     def __init__(self, *args: Any, **kwargs: Any) -> None:
# ...

# %%
# Instala las bibliotecas necesarias
# !pip install PyPDF2 openai

# Importa las bibliotecas
from PyPDF2 import PdfReader
import openai

# Configura tu clave de API de OpenAI
openai.api_key = "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"

# Define la función para leer el PDF
def leer_pdf(nombre_archivo):
    pdf_text = ""
    pdf = PdfReader(nombre_archivo)
    for page in pdf.pages:
        pdf_text += page.extract_text()
    return pdf_text

# Nombre del archivo PDF que deseas leer
nombre_archivo_pdf = "aaa.pdf"

# Lee el contenido del PDF
contenido_pdf = leer_pdf(nombre_archivo_pdf)

# Pregunta a OpenAI sobre el contenido del PDF
pregunta = "¿Cuál es la información principal en el PDF?"
respuesta = openai.Completion.create(
    engine="text-davinci-002",
    prompt=f"PDF: {contenido_pdf}\nPregunta: {pregunta}\nRespuesta:",
    max_tokens=50  # Ajusta este valor según tus necesidades
)

# Imprime la respuesta de OpenAI
print(respuesta.choices[0].text)


r este error, como esperar y reintentar más tarde
# Out:
#   File "<ipython-input-28-db30ee5fbe91>", line 39
#     respuesta = openai.Completion.create(
#     ^
# IndentationError: unexpected indent

# %%
try:
    # Tu solicitud a la API de OpenAI aquí
    respuesta = openai.Completion.create(
        engine="text-davinci-002",
        prompt=f"PDF: {contenido_pdf}\nPregunta: {pregunta}\nRespuesta:",
        max_tokens=50
    )
    # Procesa la respuesta aquí
    print(respuesta.choices[0].text)
except openai.error.RateLimitError as e:
    print(f"Error de límite de tasa: {e}")
    # Implementa una lógica para manejar este error, como esperar y reintentar más tarde
# Out:
# Error de límite de tasa: You exceeded your current quota, please check your plan and billing details.
